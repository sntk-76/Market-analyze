# %% [markdown]
# ## section 1
# As the first step, we should import the libraries that needs to be imported in project:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## section 2
# The second step is reading the csv file that contains the data that are needed for our project :

# %%
csv_file = pd.read_csv('Market.csv')
df = pd.DataFrame(csv_file)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# ## section 3
# In this project we just need to convert all the numerical columns to INT type, so we loop over the dataframe and convert all FLOAT types to INT types :

# %%
for index, row in df.iterrows():
    try:

        df.at[index, row] = int(row)
    except (ValueError, TypeError):

        continue
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# ## section 4
# There are some markets that are available in our data frame but here we just want to analyze the NYA market, so we use one of the built-in capabilities in pandas data frame and extract the rows that record the NYA market :

# %%
df = df[df['Index']=='NYA']
df
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %% [markdown]
# ## section 5
# Then we want to create a linear plot that shows us the "Adj Close" according to the time, actually this plot shows us a linear relation of the price over time :

# %%
df['Date']= pd.to_datetime(df['Date'])
plt.figure(figsize=(12,8))
plt.plot(df['Date'],df['Adj Close'])
plt.xlabel('Date')
plt.ylabel('Adj close price')
plt.title('Daily time frame')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\sina tavakoli\AppData\Local\Temp\ipykernel_14348\1521369555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date']= pd.to_datetime(df['Date'])

# %% [markdown]
# ## section 6
# We can have the summary of our data set to clarify the next steps of our process, with the full description we can understand whether is there any situation in our dataset that needs a solution or not
#
# In the cell below we can not see an obvious difference between the column count, so it means that there is not a huge difference and we can use "dropna()"
# to make them equal to make it easier for visualization and detection of the noises in plotting the columns :

# %%
df.describe()
# Out:
#                                 Date          Open          High  \
# count                          13948  13947.000000  13946.000000
# mean   1993-09-24 13:57:54.046458368   4452.147406   4469.312526
# min              1965-12-31 00:00:00    347.769989    347.769989
# 25%              1979-12-03 18:00:00    654.989990    655.150024
# 50%              1993-09-18 12:00:00   2631.909912   2632.280029
# 75%              2007-07-24 06:00:00   7339.489990   7376.315063
# max              2021-05-28 00:00:00  16590.429690  16685.890630
# std                              NaN   4074.835507   4094.956718
#
#                 Low         Close     Adj Close        Volume
# count  13945.000000  13944.000000  13938.000000  1.394700e+04
# mean    4434.262223   4453.026486   4455.094446  1.215565e+09
# min      347.769989    347.769989    347.769989  0.000000e+00
# 25%      655.039978    655.122513    655.807525  0.000000e+00
# 50%     2631.909912   2632.015014   2633.015014  0.000000e+00
# ...

# %%
df.dropna(inplace=True)
df.describe()
# Out:
# C:\Users\sina tavakoli\AppData\Local\Temp\ipykernel_14348\981677366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#                                 Date          Open          High  \
# count                          13932  13932.000000  13932.000000
# mean   1993-10-05 15:37:21.860465024   4456.384785   4473.278937
# min              1965-12-31 00:00:00    347.769989    347.769989
# 25%              1979-12-19 18:00:00    656.285004    656.392487
# 50%              1993-09-29 12:00:00   2634.024903   2634.179931
# 75%              2007-07-30 06:00:00   7348.750122   7384.077514
# max              2021-05-28 00:00:00  16590.429690  16685.890630
# std                              NaN   4074.980183   4095.100323
#
# ...

# %% [markdown]
# ## section 7
# We want to detect and remove noise from your dataset to improve the overall analysis, we can use scatter plots to identify outliers and noisy data points. To do this, consider plotting pairs of columns that are most likely to reveal noisy patterns or extreme values.
#
#    1.**Open and Close**: This pair can help you identify days with extreme price fluctuations between the opening and closing prices. Outliers in this pair may indicate noisy trading days.
#
#    2.**High and Low**:Scatter plots of 'High' and 'Low' prices can reveal days with unusually large price ranges. Extreme values in this pair might signify high volatility and potential noise.
#
#    3.**Volume and Date:** Create a line plot with 'Date' on the x-axis and 'Volume' on the y-axis to visualize how trading volume changes over time. This can help you identify days with abnormally high or low trading volume.
#
#    4.**Open and Volume:** A scatter plot of 'Open' and 'Volume' can help you detect days with unexpected trading volume relative to the opening price. Look for points that deviate significantly from the main cluster.
#
#    5.**Close and Volume:** Similar to 'Open' and 'Volume,' this pair can help you identify days with unusual trading volume relative to the closing price.
#
#    6.**High and Date / Low and Date:** Create line plots for 'High' and 'Low' prices over time to identify days with extreme daily price ranges.
#
# When creating these scatter plots, we should pay attention to data points that appear as outliers, deviating significantly from the main cluster or exhibiting patterns that do not align with the majority of data points. These outliers are potential candidates for noise removal.
#
# Once we've identified noisy data points, we can decide how to handle them, whether it's by removing them from the dataset, transforming the data, or applying statistical methods to mitigate their impact on your analysis.

# %%
plt.scatter(df['Open'],df['Close'])
plt.xlabel('Open price')
plt.ylabel('Close price')
plt.title('Open price vs Close price')
# Out:
# Text(0.5, 1.0, 'Open price vs Close price')

# %%
plt.scatter(df['High'],df['Low'])
plt.xlabel('Highest price')
plt.ylabel('Lowest price')
plt.title('Highest price vs Lowest price')
# Out:
# Text(0.5, 1.0, 'Highest price vs Lowest price')

# %%
plt.figure(figsize=(15,8))
plt.plot(df['Date'],df['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Stock Volume Over Time')
plt.xticks(rotation = 90)
# Out:
# (array([-3653.,     0.,  3652.,  7305., 10957., 14610., 18262., 21915.]),
#  [Text(-3653.0, 0, '1960'),
#   Text(0.0, 0, '1970'),
#   Text(3652.0, 0, '1980'),
#   Text(7305.0, 0, '1990'),
#   Text(10957.0, 0, '2000'),
#   Text(14610.0, 0, '2010'),
#   Text(18262.0, 0, '2020'),
#   Text(21915.0, 0, '2030')])

# %%
plt.scatter(df['Open'],df['Volume'])
plt.xlabel('Open price')
plt.ylabel('Volume')
plt.title('Openning price vs Volume')
plt.xticks(rotation = 90)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000., 18000.]),
#  [Text(-2000.0, 0, '−2000'),
#   Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000'),
#   Text(12000.0, 0, '12000'),
#   Text(14000.0, 0, '14000'),
#   Text(16000.0, 0, '16000'),
#   Text(18000.0, 0, '18000')])

# %%
plt.scatter(df['Close'],df['Volume'])
plt.xlabel('Close price')
plt.ylabel('Volume')
plt.title('Closing price vs Volume')
plt.xticks(rotation = 90)
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000., 12000.,
#         14000., 16000., 18000.]),
#  [Text(-2000.0, 0, '−2000'),
#   Text(0.0, 0, '0'),
#   Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000'),
#   Text(12000.0, 0, '12000'),
#   Text(14000.0, 0, '14000'),
#   Text(16000.0, 0, '16000'),
#   Text(18000.0, 0, '18000')])

# %% [markdown]
# ## section 8
#
# In this analysis, we are working with financial data represented in the form of a DataFrame. We aim to identify and remove noisy data points that could distort our analysis and visualizations.
#
# ### Identifying Noise
#
# We observe that there is noise in the charts, particularly in the "Open vs Close" and "High vs Low" charts. This noise is characterized by unusual data points that do not conform to the expected patterns of financial data.
#
# For instance, in the "High vs Low" chart, we notice a data point where the price is abnormal. Specifically, we are looking for data points where the following conditions are met:
#
# - The 'High' price is greater than 4000.
# - The 'High' price is less than 8000.
# - The 'Low' price is less than 2000.
#
# ### Noise Removal
#
# To address this issue, we implement a data cleaning procedure in Python. Here's how it works:
#
# 1. We identify the specific rows (data points) that meet our noise conditions using boolean indexing. These rows represent the data points we want to remove.
#
# 2. We use the `drop` method to remove these rows from our DataFrame, ensuring that the DataFrame is updated accordingly.
#
# ### Visualization
#
# After removing the noisy data points, we recreate a scatter plot to visualize the effect of the noise removal. This will help us determine if our implementation was successful in cleaning the data and improving the quality of our visualizations.

# %%
index_to_remove = df[(df['High'] > 4000) & (df['High']< 8000) & (df['Low'] < 2000)].index
df.drop(axis=0,index=index_to_remove,inplace=True)
plt.scatter(df['High'],df['Low'])
plt.xlabel('High price')
plt.ylabel('Low price')
plt.title('High price vs Low price')
# Out:
# C:\Users\sina tavakoli\AppData\Local\Temp\ipykernel_14348\1597655030.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(axis=0,index=index_to_remove,inplace=True)
# Text(0.5, 1.0, 'High price vs Low price')

# %%
index_to_remove = df[(df['Open'] > 4000) & (df['Open']< 6000) & (df['Close'] < 2000)].index
df.drop(axis=0,index=index_to_remove,inplace=True)
plt.scatter(df['Open'],df['Close'])
plt.xlabel('Open price')
plt.ylabel('Close price')
plt.title('Open price vs Close price')
# Out:
# C:\Users\sina tavakoli\AppData\Local\Temp\ipykernel_14348\54180943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(axis=0,index=index_to_remove,inplace=True)
# Text(0.5, 1.0, 'Open price vs Close price')

# %% [markdown]
# ## section 9
#
# In this section, we focus on identifying and removing noisy data from our dataset. Our analysis reveals that there are certain records with zero trading volume for several years. We consider these data points as noise and decide to eliminate them from our dataset.
#
# ## Identifying Noise
#
# We first identified noisy data points by examining charts that display relationships between "Date" and "Volume." In these charts, we noticed that there are instances where the trading volume is consistently zero for extended periods. This observation led us to conclude that these data points are not representative of typical trading behavior and can be considered outliers.
#
# We observed this trend not only in the "Date" vs "Volume" chart but also in other charts such as "Close" vs "Volume" and "Open" vs "Volume." In each case, we found that the presence of zero trading volume for extended periods indicated the need to clean the data.
#
# ## Data Cleaning
#
# To remove the noisy data from our dataset, we implemented the following steps:
#
# 1. **Identify the Starting Point:** We iterated through the "Volume" column to find the index of the first non-zero trading volume, which we stored in the variable `first_volume`.
#
# 2. **Filter the Data:** We filtered the DataFrame to keep only the data points from `first_volume` onwards. This effectively removed the records with zero trading volume for extended periods.

# %%
for index,row in enumerate(df['Volume']):
    if row > 0 :
        first_volume = index
        break

print(df.iloc[first_volume-1])
print('\n')
print(df.iloc[first_volume])    
df = df.iloc[first_volume:]
# Out:
# Index                        NYA
# Date         2001-01-02 00:00:00
# Open                 6785.689941
# High                 6785.689941
# Low                  6785.689941
# Close                6785.689941
# Adj Close            6785.689941
# Volume                       0.0
# Name: 8814, dtype: object
#
#
# Index                        NYA
# Date         2001-01-03 00:00:00
# Open                 6968.830078
# High                 6968.830078
# Low                  6968.830078
# Close                6968.830078
# Adj Close            6968.830078
# Volume              1880700000.0
# Name: 8815, dtype: object

# %%
plt.figure(figsize=(15,8))
plt.plot(df['Date'],df['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Stock Volume Over Time')
plt.xticks(rotation = 90)
# Out:
# (array([ 9496., 10957., 12418., 13879., 15340., 16801., 18262., 19723.]),
#  [Text(9496.0, 0, '1996'),
#   Text(10957.0, 0, '2000'),
#   Text(12418.0, 0, '2004'),
#   Text(13879.0, 0, '2008'),
#   Text(15340.0, 0, '2012'),
#   Text(16801.0, 0, '2016'),
#   Text(18262.0, 0, '2020'),
#   Text(19723.0, 0, '2024')])

# %%
df = df[df['Volume']<0.9*1e10]
plt.scatter(df['Open'],df['Volume'])
plt.xlabel('Open price')
plt.ylabel('Volume')
plt.title('Openning price vs Volume')
plt.xticks(rotation = 90)
# Out:
# (array([ 2000.,  4000.,  6000.,  8000., 10000., 12000., 14000., 16000.,
#         18000.]),
#  [Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000'),
#   Text(12000.0, 0, '12000'),
#   Text(14000.0, 0, '14000'),
#   Text(16000.0, 0, '16000'),
#   Text(18000.0, 0, '18000')])

# %%
plt.scatter(df['Close'],df['Volume'])
plt.xlabel('Close price')
plt.ylabel('Volume')
plt.title('Closing price vs Volume')
plt.xticks(rotation = 90)
# Out:
# (array([ 2000.,  4000.,  6000.,  8000., 10000., 12000., 14000., 16000.,
#         18000.]),
#  [Text(2000.0, 0, '2000'),
#   Text(4000.0, 0, '4000'),
#   Text(6000.0, 0, '6000'),
#   Text(8000.0, 0, '8000'),
#   Text(10000.0, 0, '10000'),
#   Text(12000.0, 0, '12000'),
#   Text(14000.0, 0, '14000'),
#   Text(16000.0, 0, '16000'),
#   Text(18000.0, 0, '18000')])
